# %%
# %load_ext autoreload
# %autoreload 2

import csv
import json
import os
import pandas as pd
import papermill as pm
import re
import scrapbook as sb
import uuid

from functions import gpt

from tqdm.notebook import tqdm_notebook
tqdm_notebook().pandas()

pd.set_option('display.max_colwidth', None)

from pylatexenc.latexwalker import LatexWalker, LatexMathNode, LatexMacroNode, LatexGroupNode, LatexCharsNode, LatexEnvironmentNode
# Out:
# 0it [00:00, ?it/s]

# %%
base_name = "2021_Hashimoto_Neural_ODE_and_holographic_QCD_PUB"
project_folder = "diygenomics-projects"
sub_category = "math"
work_bucket = "AdS-CFT"
external_id = "2023_05_22_92dc0613b4493d7b5847g"

# %%
data_path = os.getenv('DATA_PATH')
file_path = lambda *args: os.path.join(data_path, project_folder, sub_category, work_bucket,
                                       base_name, 'mathpix', *args)

model = 'gpt-4' # 'gpt-3.5-turbo' # 'gpt-4'
index_col = 'uuid'

input_file = f'{external_id}.lines.json'

# %%
with open(file_path(input_file), 'r') as f:
    data = json.load(f)

# %%
pattern = r'^\([A-Za-z]?\d+(\.\d+)?\)$'

text_nodes = []
captured_math = []

for page in data['pages']:
    for line in page['lines']:
        text = line['text']
        
        if re.match(pattern, text):
            current_annotations = []
            current_annotations.append(text)
            if len(text_nodes) > 0:
                while len(text_nodes) > 0: #  and re.match(pattern, text_nodes[offset]['text'])
                    previous_line = text_nodes.pop()
                    if re.match(pattern, previous_line['text']):
                        current_annotations.append(previous_line['text'])
                    else:
                        captured_math.append((previous_line['text'], current_annotations))
                        break
        
        text_nodes.append(line)

# %%
begin_gathered_pattern = r'\\begin{gathered}\n\\'
end_gathered_pattern = r'\\end{gathered}\n\\'
begin_gathered_no_newline_pattern = r'\\begin{gathered}'
end_gathered_no_newline_pattern = r'\\end{gathered}'
begin_gathered_bracket_pattern = '\[\n'
end_gathered_bracket_pattern = '\n]'

modified_tuples = []
tuples = captured_math
for i in range(len(tuples)):
    if len(tuples[i][1]) > 1:
        prior_tuple = modified_tuples.pop()
        original_math = prior_tuple[0]
        original_annotations = tuples[i][1][::-1]
        maths = original_math.split("\\\\")
        for index, math in enumerate(maths):
            math = re.sub(begin_gathered_pattern, '', math)
            math = re.sub(end_gathered_pattern, '', math)
            math = re.sub(begin_gathered_no_newline_pattern, '', math)
            math = re.sub(end_gathered_no_newline_pattern, '', math)
            math = re.sub(begin_gathered_bracket_pattern, '', math)
            math = re.sub(end_gathered_bracket_pattern, '', math)
            modified_tuples.append((math, original_annotations[index]))
    else:
        modified_tuples.append((tuples[i][0], tuples[i][1][0]))

# %%
uuids = [uuid.uuid4() for _ in range(len(modified_tuples))]

df = pd.DataFrame(modified_tuples, columns=['math', 'paper_annotation'], index=uuids)
df = df.rename_axis('uuid', axis='index')

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                              math
# uuid
# 6998d986-fca2-4650-a4bd-4656e657fa72                                                                                                                                                                                                                \[\n\mathrm{d} s^{2}=-f(\eta) \mathrm{d} t^{2}+\mathrm{d} \eta^{2}+g(\eta)\left(\mathrm{d} x_{1}^{2}+\cdots+\mathrm{d} x_{d-1}^{2}\right)\n\]  \
# 340ffe88-4db9-43d5-b5e1-fbf4eb392df0                                                                                                                                                                                                                                                                                 \[\n\sqrt{|g|}=\sqrt{-\operatorname{det} g}=\sqrt{f(\eta) g(\eta)^{d-1}}\n\]
# 52828cb3-4ebb-4c28-9e71-fcbafa108f52                                                                                                                                                                                                      \[\nS[\phi]=\frac{1}{2} \int \sqrt{|g|}\left(g^{\mu \nu} \partial_{\mu} \phi \partial_{\nu} \phi+m^{2} \phi^{2}+\frac{\lambda}{2} \phi^{4}\right) .\n\]
# 6ab19ac6-9607-4aa4-8ffc-c37867a8799c                                                                                                                                                                                                                            \[\n-\frac{1}{\sqrt{|g|}} \partial_{\mu}\left(\sqrt{|g|} g^{\mu \nu} \partial_{\nu} \phi\right)+m^{2} \phi+\lambda \phi^{3}=0\n\]
# 13619afb-215e-4b83-ab99-0c57d8a6df11                                                                                                                                                                                                                             \[\n-\partial_{\eta}^{2} \phi-\left(\partial_{\eta} \ln \sqrt{|g|}\right) \partial_{\eta} \phi+m^{2} \phi+\lambda \phi^{3}=0\n\]
# b557096d-7cbc-4f93-b7a7-6a1618e13023                                                                                                                                                                                                                      \[\n\begin{aligned}\n& \pi=\partial_{\eta} \phi, \\\n& \partial_{\eta} \pi+h(\eta) \pi-m^{2} \phi-\lambda \phi^{3}=0\n\end{aligned}\n\]
# e48cc84e-d9ea-47bc-9a0f-fa3feddbe015                                                                                                                                                                                                                                                                                      \[\nh(\eta) \equiv \partial_{\eta} \ln \sqrt{f(\eta) g(\eta)^{d-1}}\n\]
# 7d595253-663a-41c1-bad2-49a585f3284f                                                                                                                                                                                                                                                                          \[\n\left[\frac{2}{\eta} \pi-m^{2} \phi-\lambda \phi^{3}\right]_{\eta \sim 0}=0\n\]
# 74d665ac-0ad8-474c-95ac-9d20e1e022f3                                                                                                                                                                                                                                                                                                                                   \[\n\pi(\eta \sim 0)=0\n\]
# 932593b2-bc00-46c0-a9a8-4ef78354a742                                                                                                                                                                                                                               \[\nL^{3 / 2} \phi \sim \alpha e^{-\eta / L}+\beta e^{-3 \eta / L}-\frac{\lambda \alpha^{3}}{2 L^{2}} \eta e^{-3 \eta / L}\n\]
# 564b67f6-52c5-4556-ba77-24b691ecabc6                                                                                                                                                                                                                               \[\n\alpha=\frac{\sqrt{N_{c}}}{2 \pi} m_{\mathcal{O}}, \quad \beta=\frac{\pi}{\sqrt{N_{c}}}\langle\mathcal{O}\rangle L^{3}\n\]
# 772584a6-c2bf-4d19-9246-e9d6cc601ff5                                                                                                                                                                                                                                                                                             \[\n\frac{\mathrm{d} z(t)}{\mathrm{d} t}=f_{\theta}(z(t), t)\n\]
# 61551755-09cf-4bb6-9193-b8ca51a2da38                                                                                                                                                                                                                                         \[\n\mathcal{L}\left(z_{1}\right)=\mathcal{L}\left(\int_{t_{0}}^{t_{1}} \mathrm{~d} t f_{\theta}(z(t), t)\right)\n\]
# 0bcd3675-acc3-4a2b-b07f-5bf8a602a14d                                                                                                                                                                                                                                                              \[\n\frac{\mathrm{d} a(t)}{\mathrm{d} t}=-a(t) \cdot \frac{\partial f_{\theta}}{\partial z}\n\]
# 05e263f0-e962-47ab-9f14-f1bd30650ce2                                                                                                                                                                                                              \[\n\frac{\partial \mathcal{L}}{\partial \theta}=\int_{t_{1}}^{t_{0}} a(t) \cdot \frac{\partial f_{\theta}}{\partial \theta} \mathrm{d} t .\n\]
# 47878d9d-d180-427e-b803-4b3f305d2c33                                                                                                                                                                                                                                                                                          \[\n(\pi, \phi) \leftrightarrow z, \quad \eta \leftrightarrow t\n\]
# 0c3e2595-ae49-4a6a-b272-fe09d7dac977                                                                                                                                                                                                                                                                                   ansatz 1: $h(\widetilde{\eta})=\sum_{n=0}^{8} a_{n} \widetilde{\eta}^{n}$,
# 9bc76888-cb9d-4052-96a3-a8f193589464                                                                                                                                                                                                                                       \[\n\text { ansatz 2: } h(\widetilde{\eta})=\sum_{n=0}^{8} b_{n} \widetilde{\eta}^{n}+\frac{1}{1-\widetilde{\eta}}\n\]
# 01242b75-f639-4704-97f9-bc5951acdad0                                                                                                                          \[\n\mathcal{L}=\frac{1}{N_{\text {data }}} \sum_{\text {data }}\left[\left|T\left(\pi\left(\eta_{\text {fin }}\right) ; \epsilon, \sigma\right)-l\right|^{2}+\beta\left(h\left(\eta_{\text {int }}\right)-4\right)^{2}\right],\n\]
# 240a050b-24d7-4155-b6ea-a3a431247b75                                                                                                                                                                                                                  \[\nT(x ; \epsilon, \sigma)=1+0.5\left(\tanh \left(\frac{x-\epsilon}{\sigma}\right)-\tanh \left(\frac{x+\epsilon}{\sigma}\right)\right)\n\]
# 9f5e534a-de79-451b-b4fc-e087bda02e24                                                    \[\n\begin{aligned}\nh(\eta)= & 8.2352 \widetilde{\eta}^{8}+8.0109 \widetilde{\eta}^{7}+7.6072 \widetilde{\eta}^{6} \\\n& +6.9469 \widetilde{\eta}^{5}+150.89 \widetilde{\eta}^{4}-130.81 \widetilde{\eta}^{3} \\\n& +55.539 \widetilde{\eta}^{2}-22.223 \widetilde{\eta}^{1}+3.7720 .\n\end{aligned}\n\]
# e5d75827-1a42-43cc-9d58-ce4fefebddb2                                                                                                                                                                                                                                                                                                                                              \lambda=0.0004
# a27f8ea0-f80f-4c97-80f8-a3ecfdf03d07                                                                                                                                                                                                                                                                                                                   \nL=5.1640\left[\mathrm{GeV}^{-1}\right] .
# 44c8fb5a-23b5-4c55-b42e-09da5b63b3d0                                                                                                                                                                                                                                                                                                   \[\ng(\eta)=A\left(\cosh \frac{2 \eta}{L a}\right)^{a}\n\]
# 2ed0ec1e-4dc9-48de-8e14-b243c16f1b8f                                                                                                                                                                                                                                                                                                                   \[\nf(\eta) \sim(2 \pi T)^{2} \eta^{2}\n\]
# d08f29ce-cdbb-432b-bc63-6b0cf61e5530                                                                                                                                                                                                                                                                                                  \[\nf(\eta)=(2 \pi T L)^{2}(\tanh \eta / L)^{2} F(\eta)\n\]
# 52bed2fe-3408-408f-8572-99cd22953e70                                                                                                                                                                                                                                                                                                                 \[\n\lim _{\eta \rightarrow 0} F(\eta)=1\n\]
# 8faa8dea-cc7c-4f00-8d22-9eb3297af90f                                                                                                                                                                                                                        \[\nF(\eta)=\exp \int_{0}^{\eta}\left(2 h(\eta)-\frac{4}{L \sinh (2 \eta / L)}-\frac{6}{L} \tanh \frac{2 \eta}{L a}\right) d \eta\n\]
# 9777d1da-042c-45e2-ba27-d759a298c5c2                                                                                                                                                                                                                                                                                        \[\nf(\eta) \simeq g(\eta) \simeq e^{2 \eta / L+\text { const. }}\n\]
# eddd2351-215e-4ab7-8273-e2647d1b71e2                                                                                                                                              \[\n\begin{aligned}\n& \int_{0}^{\eta}\left(2 h(\eta)-\frac{4}{L \sinh (2 \eta / L)}-\frac{6}{L} \tanh \frac{2 \eta}{L a}\right) d \eta \\\n& =\frac{2 \eta}{L}+c(a)+\mathcal{O}(1 / \eta) .\n\end{aligned}\n\]
# df182e7a-5607-4e7a-aa6c-11c73b0e3d04                                                                                                                                                                                                                                                                          \[\ng(\eta)=(2 \pi T L)^{2} e^{c(a)}\left(2 \cosh \frac{2 \eta}{L a}\right)^{a}\n\]
# 3ad5656f-43fe-497b-a49e-927c89eb1ab3                                                                                                                                                                                                                                                                                          \[\n\frac{\partial}{\partial T}\left[T^{2} e^{c(a(T))}\right]=0\n\]
# c44f263e-e8e2-408b-9c82-02f99db8d8f5                                                                                                                                                                 \\nd=2 \int_{\eta_{0}}^{\infty} \frac{1}{\sqrt{g(\eta)}} \sqrt{\frac{f\left(\eta_{0}\right) g\left(\eta_{0}\right)}{f(\eta) g(\eta)-f\left(\eta_{0}\right) g\left(\eta_{0}\right)}} d \eta,
# ba97a7bf-edd0-4a2f-92c5-10c6be9e0444                                                                                                                                                        \n2 \pi \alpha^{\prime} V=2 \int_{\eta_{0}}^{\infty} \sqrt{f(\eta)} \sqrt{\frac{f\left(\eta_{0}\right) g\left(\eta_{0}\right)}{f(\eta) g(\eta)-f\left(\eta_{0}\right) g\left(\eta_{0}\right)}} d \eta
# cf9a2350-0fc9-4857-9eab-1247ec77b152                                                                                                                                                                                                                                                                 \[\n2 \pi \alpha^{\prime} V_{\text {Debye }}=2 \int_{0}^{\eta_{0}} \sqrt{f(\eta)} d \eta\n\]
# 76439673-f72f-4d76-ac30-118b082e35cb                                                                                                                                                                                                                                                                                                 \[\n\frac{d x_{i}(t)}{d t}=v_{i}(\vec{x}(t), t ; \theta)\n\]
# ed116b49-9dae-4a52-a89a-0ed0543c4c5a                                                                                                                                                                                                                                                                                                                  \[\n\mathcal{L}=\mathcal{L}(\vec{x}(1))\n\]
# 2d2d76ae-ba2b-4d6a-a3e8-da03bd4163b9                                                                                                                                                                                                                                                                                              \[\na_{i}(t)=\frac{\partial \mathcal{L}}{\partial x_{i}(t)}\n\]
# 56b940ff-5be5-4899-a414-504bbffe8c14                                                                                                                                                                                                    \[\n\frac{\partial \mathcal{L}}{\partial x_{i}(t)}=\frac{\partial \mathcal{L}}{\partial x_{j}(t+d t)} \frac{\partial x_{j}(t+d t)}{\partial x_{i}(t)}\n\]
# 5dccfa59-95f3-4228-9fa4-6b16f6ebc565                                                                                             \[\n\begin{aligned}\na_{i}(t) & =a_{j}(t+d t) \frac{\partial\left[x_{j}(t)+v_{j}(\vec{x}(t), t ; \theta) d t\right]}{\partial x_{i}(t)} \\\n& =\left(\delta_{i j}+\partial_{x_{i}(t)} v_{j}(\vec{x}(t), t ; \theta) d t\right) a_{j}(t+d t) .\n\end{aligned}\n\]
# b231adf2-956f-4379-8c14-23564f848f3b                                                                                                                                                                                                                                                                         \frac{d a_{i}(t)}{d t}=-a_{j}(t) \partial_{x_{i}(t)} v_{j}(\vec{x}(t), t ; \theta),
# 3406436c-7eca-4ab4-8214-f6dfa1e39c64                                                                                                                                                                                                                                                                        \na_{i}(0)=\int_{1}^{0} a_{j}(t) \partial_{x_{i}(t)} v_{j}(\vec{x}, t ; \theta) d t .
# ac439a40-2864-4f04-91bd-c6d0f40f9bc5  \[\n\begin{aligned}\n\frac{\partial \mathcal{L}}{\partial \theta} & =\int_{1}^{0} \frac{\partial \mathcal{L}}{\partial x_{i}(t)} \frac{\partial\left(x_{i}(t)-x_{i}(t-d t)\right)}{\partial \theta} \\\n& =\int_{1}^{0} \frac{\partial \mathcal{L}}{\partial x_{i}(t)} \frac{\partial v_{i}(\vec{x}, t ; \theta)}{\partial \theta} d t .\n\end{aligned}\n\]
#
#                                      paper_annotation
# uuid
# 6998d986-fca2-4650-a4bd-4656e657fa72              (1)
# 340ffe88-4db9-43d5-b5e1-fbf4eb392df0              (2)
# 52828cb3-4ebb-4c28-9e71-fcbafa108f52              (3)
# 6ab19ac6-9607-4aa4-8ffc-c37867a8799c              (4)
# 13619afb-215e-4b83-ab99-0c57d8a6df11              (5)
# b557096d-7cbc-4f93-b7a7-6a1618e13023              (6)
# e48cc84e-d9ea-47bc-9a0f-fa3feddbe015              (7)
# 7d595253-663a-41c1-bad2-49a585f3284f              (8)
# 74d665ac-0ad8-474c-95ac-9d20e1e022f3              (9)
# 932593b2-bc00-46c0-a9a8-4ef78354a742             (10)
# 564b67f6-52c5-4556-ba77-24b691ecabc6             (11)
# 772584a6-c2bf-4d19-9246-e9d6cc601ff5             (12)
# 61551755-09cf-4bb6-9193-b8ca51a2da38             (13)
# 0bcd3675-acc3-4a2b-b07f-5bf8a602a14d             (14)
# 05e263f0-e962-47ab-9f14-f1bd30650ce2             (15)
# 47878d9d-d180-427e-b803-4b3f305d2c33             (16)
# 0c3e2595-ae49-4a6a-b272-fe09d7dac977             (17)
# 9bc76888-cb9d-4052-96a3-a8f193589464             (18)
# 01242b75-f639-4704-97f9-bc5951acdad0             (19)
# 240a050b-24d7-4155-b6ea-a3a431247b75             (20)
# 9f5e534a-de79-451b-b4fc-e087bda02e24             (21)
# e5d75827-1a42-43cc-9d58-ce4fefebddb2             (22)
# a27f8ea0-f80f-4c97-80f8-a3ecfdf03d07             (23)
# 44c8fb5a-23b5-4c55-b42e-09da5b63b3d0             (24)
# 2ed0ec1e-4dc9-48de-8e14-b243c16f1b8f             (25)
# d08f29ce-cdbb-432b-bc63-6b0cf61e5530             (26)
# 52bed2fe-3408-408f-8572-99cd22953e70             (27)
# 8faa8dea-cc7c-4f00-8d22-9eb3297af90f             (28)
# 9777d1da-042c-45e2-ba27-d759a298c5c2             (29)
# eddd2351-215e-4ab7-8273-e2647d1b71e2             (30)
# df182e7a-5607-4e7a-aa6c-11c73b0e3d04             (31)
# 3ad5656f-43fe-497b-a49e-927c89eb1ab3             (32)
# c44f263e-e8e2-408b-9c82-02f99db8d8f5             (33)
# ba97a7bf-edd0-4a2f-92c5-10c6be9e0444             (34)
# cf9a2350-0fc9-4857-9eab-1247ec77b152             (35)
# 76439673-f72f-4d76-ac30-118b082e35cb             (A1)
# ed116b49-9dae-4a52-a89a-0ed0543c4c5a             (A2)
# 2d2d76ae-ba2b-4d6a-a3e8-da03bd4163b9             (A3)
# 56b940ff-5be5-4899-a414-504bbffe8c14             (A4)
# 5dccfa59-95f3-4228-9fa4-6b16f6ebc565             (A5)
# b231adf2-956f-4379-8c14-23564f848f3b             (A6)
# 3406436c-7eca-4ab4-8214-f6dfa1e39c64             (A7)
# ac439a40-2864-4f04-91bd-c6d0f40f9bc5             (A8)

# %%
df.to_csv(file_path('extracted_annotated_math.csv'), quoting=csv.QUOTE_MINIMAL)

# %%
# text_nodes = []

# for page in data['pages']:
#     for line in page['lines']:
#         text = line['text']
        
#         if re.match(pattern, text):
#             if previous_line is not None:
#                 if re.match(pattern, previous_line['text']):
#                     print(previous_line['text'])
        
#         previous_line = line
